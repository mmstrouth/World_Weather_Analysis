# %% [markdown]
# Deliverable 1. Retrieve Weather Data.
# Create a folder called Weather_Database to save all the files related with this deliverable.
#
# Save the Weather_Database_starter_code.ipynb starter code to the Weather_Database folder and rename it as Weather_Database.ipynb.
#
# Use the np.random.uniform function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# Use the citipy module to get the nearest city for each latitude and longitude combination.
#
# Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the config.py file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# Retrieve the following information from the API call:
#
# Latitude and longitude
#
# Maximum temperature
#
# Percent humidity
#
# Percent cloudiness
#
# Wind speed
#
# Weather description (for example, clouds, fog, light rain, clear sky)
#
# Add the weather data to a new DataFrame.
#
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import json

# %% [markdown]
# Use the np.random.uniform function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# Use the citipy module to get the nearest city for each latitude and longitude combination.

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %% [markdown]
# Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the config.py file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Look at the json to determine where current description is
city_url = url + "&q=" + city.replace(" ","+")
data = requests.get(city_url).json()
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -53.15,
#         "lon": -70.9167
#     },
#     "dt": 1672179708,
#     "id": 3874787,
#     "main": {
#         "feels_like": 39.45,
#         "humidity": 57,
#         "pressure": 1008,
#         "temp": 48.31,
#         "temp_max": 50.11,
#         "temp_min": 48.31
#     },
#     "name": "Punta Arenas",
#     "sys": {
#         "country": "CL",
#         "id": 8487,
#         "sunrise": 1672129002,
#         "sunset": 1672189953,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 260,
#         "gust": 43.73,
#         "speed": 32.21
#     }
# }

# %% [markdown]
# Retrieve the following information from the API call.
# The latitude and longitude
# The Max temperature
# The % humidity
# The % cloudiness
# The Wind speed
# The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | takanabe
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 4 of Set 1 | tuktoyaktuk
# Processing Record 5 of Set 1 | yellowknife
# Processing Record 6 of Set 1 | butaritari
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 1 | provideniya
# Processing Record 10 of Set 1 | brezovica pri ljubljani
# Processing Record 11 of Set 1 | nikolskoye
# Processing Record 12 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 1 | new norfolk
# Processing Record 14 of Set 1 | jaru
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 1 | hede
# Processing Record 18 of Set 1 | ilulissat
# Processing Record 19 of Set 1 | pacific grove
# Processing Record 20 of Set 1 | teguise
# Processing Record 21 of Set 1 | saldanha
# Processing Record 22 of Set 1 | katobu
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | esperance
# Processing Record 26 of Set 1 | katsuura
# Processing Record 27 of Set 1 | dikson
# Processing Record 28 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | vila do maio
# Processing Record 31 of Set 1 | carnarvon
# Processing Record 32 of Set 1 | padang
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | bambanglipuro
# Processing Record 35 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 1 | hithadhoo
# Processing Record 37 of Set 1 | vorotynets
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 40 of Set 1 | sao joao da barra
# Processing Record 41 of Set 1 | crab hill
# City not found. Skipping...
# Processing Record 42 of Set 1 | bambous virieux
# Processing Record 43 of Set 1 | khatanga
# Processing Record 44 of Set 1 | derzhavinsk
# Processing Record 45 of Set 1 | kahului
# Processing Record 46 of Set 1 | kieta
# Processing Record 47 of Set 1 | temirtau
# Processing Record 48 of Set 1 | matara
# Processing Record 49 of Set 1 | college
# Processing Record 50 of Set 1 | roald
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | westport
# Processing Record 3 of Set 2 | cabo san lucas
# Processing Record 4 of Set 2 | scottsburgh
# City not found. Skipping...
# Processing Record 5 of Set 2 | pisco
# Processing Record 6 of Set 2 | nioro
# Processing Record 7 of Set 2 | atuona
# Processing Record 8 of Set 2 | hermanus
# Processing Record 9 of Set 2 | abomsa
# Processing Record 10 of Set 2 | talnakh
# Processing Record 11 of Set 2 | sao filipe
# Processing Record 12 of Set 2 | bethel
# Processing Record 13 of Set 2 | chuy
# Processing Record 14 of Set 2 | finschhafen
# Processing Record 15 of Set 2 | atar
# Processing Record 16 of Set 2 | atikokan
# Processing Record 17 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 2 | kawambwa
# Processing Record 19 of Set 2 | kapaa
# Processing Record 20 of Set 2 | paamiut
# Processing Record 21 of Set 2 | grindavik
# Processing Record 22 of Set 2 | chokurdakh
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | hilo
# Processing Record 25 of Set 2 | arraial do cabo
# Processing Record 26 of Set 2 | monteagudo
# Processing Record 27 of Set 2 | cape town
# Processing Record 28 of Set 2 | thompson
# Processing Record 29 of Set 2 | paita
# Processing Record 30 of Set 2 | ibra
# Processing Record 31 of Set 2 | north branch
# Processing Record 32 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 33 of Set 2 | krasnyy chikoy
# Processing Record 34 of Set 2 | saint-philippe
# Processing Record 35 of Set 2 | port elizabeth
# Processing Record 36 of Set 2 | ginda
# Processing Record 37 of Set 2 | east london
# Processing Record 38 of Set 2 | geraldton
# Processing Record 39 of Set 2 | nantucket
# Processing Record 40 of Set 2 | tiarei
# Processing Record 41 of Set 2 | bredasdorp
# Processing Record 42 of Set 2 | sorong
# Processing Record 43 of Set 2 | isangel
# Processing Record 44 of Set 2 | yulara
# Processing Record 45 of Set 2 | airai
# Processing Record 46 of Set 2 | atbasar
# Processing Record 47 of Set 2 | flin flon
# Processing Record 48 of Set 2 | hobart
# Processing Record 49 of Set 2 | hasaki
# Processing Record 50 of Set 2 | faanui
# Processing Record 1 of Set 3 | north bend
# Processing Record 2 of Set 3 | yar-sale
# Processing Record 3 of Set 3 | jamestown
# Processing Record 4 of Set 3 | triunfo
# Processing Record 5 of Set 3 | pevek
# Processing Record 6 of Set 3 | klyuchi
# Processing Record 7 of Set 3 | mar del plata
# Processing Record 8 of Set 3 | san patricio
# Processing Record 9 of Set 3 | souillac
# Processing Record 10 of Set 3 | esso
# Processing Record 11 of Set 3 | hay river
# Processing Record 12 of Set 3 | humberto de campos
# Processing Record 13 of Set 3 | vila franca do campo
# Processing Record 14 of Set 3 | dzilam gonzalez
# Processing Record 15 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 3 | srandakan
# Processing Record 17 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 18 of Set 3 | tiznit
# Processing Record 19 of Set 3 | banda aceh
# Processing Record 20 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 3 | leningradskiy
# Processing Record 22 of Set 3 | pusad
# Processing Record 23 of Set 3 | ipeti
# City not found. Skipping...
# Processing Record 24 of Set 3 | bokspits
# City not found. Skipping...
# Processing Record 25 of Set 3 | eyemouth
# Processing Record 26 of Set 3 | seminole
# Processing Record 27 of Set 3 | asau
# Processing Record 28 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 29 of Set 3 | goderich
# Processing Record 30 of Set 3 | doctor juan leon mallorquin
# Processing Record 31 of Set 3 | paytug
# City not found. Skipping...
# Processing Record 32 of Set 3 | qaanaaq
# Processing Record 33 of Set 3 | lompoc
# Processing Record 34 of Set 3 | camacha
# Processing Record 35 of Set 3 | port hardy
# Processing Record 36 of Set 3 | georgetown
# Processing Record 37 of Set 3 | vaini
# Processing Record 38 of Set 3 | pemangkat
# Processing Record 39 of Set 3 | codrington
# Processing Record 40 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 3 | kattivakkam
# Processing Record 42 of Set 3 | half moon bay
# Processing Record 43 of Set 3 | barrow
# Processing Record 44 of Set 3 | kurtamysh
# Processing Record 45 of Set 3 | nikolayevka
# Processing Record 46 of Set 3 | palaikastron
# Processing Record 47 of Set 3 | cherskiy
# Processing Record 48 of Set 3 | tari
# Processing Record 49 of Set 3 | hami
# Processing Record 50 of Set 3 | tasiilaq
# Processing Record 1 of Set 4 | muisne
# Processing Record 2 of Set 4 | whitehorse
# Processing Record 3 of Set 4 | olafsvik
# Processing Record 4 of Set 4 | mozhga
# Processing Record 5 of Set 4 | jiwani
# Processing Record 6 of Set 4 | taltal
# Processing Record 7 of Set 4 | santa cruz del sur
# Processing Record 8 of Set 4 | dedovichi
# Processing Record 9 of Set 4 | jalu
# Processing Record 10 of Set 4 | kachiry
# Processing Record 11 of Set 4 | nanortalik
# Processing Record 12 of Set 4 | shepsi
# Processing Record 13 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 4 | emerald
# Processing Record 15 of Set 4 | nueve de julio
# Processing Record 16 of Set 4 | lebu
# Processing Record 17 of Set 4 | vila velha
# Processing Record 18 of Set 4 | castro
# Processing Record 19 of Set 4 | konevo
# Processing Record 20 of Set 4 | stepnogorsk
# Processing Record 21 of Set 4 | praia da vitoria
# Processing Record 22 of Set 4 | mogadishu
# Processing Record 23 of Set 4 | palmas bellas
# Processing Record 24 of Set 4 | watertown
# Processing Record 25 of Set 4 | avarua
# Processing Record 26 of Set 4 | gimli
# Processing Record 27 of Set 4 | tura
# Processing Record 28 of Set 4 | tezu
# Processing Record 29 of Set 4 | manavalakurichi
# Processing Record 30 of Set 4 | luderitz
# Processing Record 31 of Set 4 | korla
# Processing Record 32 of Set 4 | mahebourg
# Processing Record 33 of Set 4 | nome
# Processing Record 34 of Set 4 | fort nelson
# Processing Record 35 of Set 4 | poum
# Processing Record 36 of Set 4 | baghdad
# Processing Record 37 of Set 4 | mbamba
# Processing Record 38 of Set 4 | alofi
# Processing Record 39 of Set 4 | gizo
# Processing Record 40 of Set 4 | tubarao
# Processing Record 41 of Set 4 | mount gambier
# Processing Record 42 of Set 4 | moose factory
# Processing Record 43 of Set 4 | cidreira
# Processing Record 44 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 4 | keti bandar
# Processing Record 46 of Set 4 | naryan-mar
# Processing Record 47 of Set 4 | victoria
# Processing Record 48 of Set 4 | rio gallegos
# Processing Record 49 of Set 4 | corbelia
# Processing Record 50 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 5 | husavik
# Processing Record 2 of Set 5 | ascona
# Processing Record 3 of Set 5 | mattru
# Processing Record 4 of Set 5 | bela
# Processing Record 5 of Set 5 | kijaba
# City not found. Skipping...
# Processing Record 6 of Set 5 | broome
# Processing Record 7 of Set 5 | jaleswar
# Processing Record 8 of Set 5 | saint george
# Processing Record 9 of Set 5 | pichayevo
# Processing Record 10 of Set 5 | sao felix do xingu
# Processing Record 11 of Set 5 | lerwick
# Processing Record 12 of Set 5 | coquimbo
# Processing Record 13 of Set 5 | taoudenni
# Processing Record 14 of Set 5 | robertsport
# Processing Record 15 of Set 5 | kloulklubed
# Processing Record 16 of Set 5 | shetpe
# Processing Record 17 of Set 5 | juneau
# Processing Record 18 of Set 5 | port lincoln
# Processing Record 19 of Set 5 | salinas
# Processing Record 20 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 5 | deputatskiy
# Processing Record 22 of Set 5 | weihe
# Processing Record 23 of Set 5 | seguela
# Processing Record 24 of Set 5 | owando
# Processing Record 25 of Set 5 | guilin
# Processing Record 26 of Set 5 | itarema
# Processing Record 27 of Set 5 | vostok
# Processing Record 28 of Set 5 | raga
# Processing Record 29 of Set 5 | torbay
# Processing Record 30 of Set 5 | kasungu
# Processing Record 31 of Set 5 | sofiysk
# City not found. Skipping...
# Processing Record 32 of Set 5 | sorland
# Processing Record 33 of Set 5 | marrakesh
# Processing Record 34 of Set 5 | kodiak
# Processing Record 35 of Set 5 | tomatlan
# Processing Record 36 of Set 5 | dabat
# Processing Record 37 of Set 5 | nyakahanga
# Processing Record 38 of Set 5 | natal
# Processing Record 39 of Set 5 | tuatapere
# Processing Record 40 of Set 5 | ribeira grande
# Processing Record 41 of Set 5 | tautira
# Processing Record 42 of Set 5 | saint charles
# Processing Record 43 of Set 5 | altoona
# Processing Record 44 of Set 5 | mana
# Processing Record 45 of Set 5 | sakaraha
# Processing Record 46 of Set 5 | gweta
# Processing Record 47 of Set 5 | kaitangata
# Processing Record 48 of Set 5 | kisumu
# Processing Record 49 of Set 5 | seydi
# Processing Record 50 of Set 5 | haines junction
# Processing Record 1 of Set 6 | lorengau
# Processing Record 2 of Set 6 | samarai
# Processing Record 3 of Set 6 | vanimo
# Processing Record 4 of Set 6 | porto novo
# Processing Record 5 of Set 6 | barra dos coqueiros
# Processing Record 6 of Set 6 | general roca
# Processing Record 7 of Set 6 | maloy
# Processing Record 8 of Set 6 | kenai
# Processing Record 9 of Set 6 | havre-saint-pierre
# Processing Record 10 of Set 6 | ayan
# Processing Record 11 of Set 6 | marienburg
# Processing Record 12 of Set 6 | namatanai
# Processing Record 13 of Set 6 | la ronge
# Processing Record 14 of Set 6 | cayenne
# Processing Record 15 of Set 6 | marsaxlokk
# Processing Record 16 of Set 6 | chepareria
# Processing Record 17 of Set 6 | dien bien
# City not found. Skipping...
# Processing Record 18 of Set 6 | huarmey
# Processing Record 19 of Set 6 | mucurapo
# Processing Record 20 of Set 6 | kismayo
# Processing Record 21 of Set 6 | broken hill
# Processing Record 22 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 23 of Set 6 | mizdah
# Processing Record 24 of Set 6 | sioux lookout
# Processing Record 25 of Set 6 | saint-augustin
# Processing Record 26 of Set 6 | huambo
# Processing Record 27 of Set 6 | lewistown
# Processing Record 28 of Set 6 | ambon
# Processing Record 29 of Set 6 | kidal
# Processing Record 30 of Set 6 | ouahigouya
# Processing Record 31 of Set 6 | sibolga
# Processing Record 32 of Set 6 | omsukchan
# Processing Record 33 of Set 6 | yaring
# Processing Record 34 of Set 6 | waipawa
# Processing Record 35 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 36 of Set 6 | seoul
# Processing Record 37 of Set 6 | necochea
# Processing Record 38 of Set 6 | shingu
# Processing Record 39 of Set 6 | ulladulla
# Processing Record 40 of Set 6 | vardo
# Processing Record 41 of Set 6 | soto la marina
# Processing Record 42 of Set 6 | qaqortoq
# Processing Record 43 of Set 6 | inhambane
# Processing Record 44 of Set 6 | zarinsk
# Processing Record 45 of Set 6 | yagodnoye
# Processing Record 46 of Set 6 | yaounde
# Processing Record 47 of Set 6 | kropotkin
# Processing Record 48 of Set 6 | kavaratti
# Processing Record 49 of Set 6 | san angelo
# Processing Record 50 of Set 6 | arlit
# Processing Record 1 of Set 7 | ponta do sol
# Processing Record 2 of Set 7 | te anau
# Processing Record 3 of Set 7 | yaan
# Processing Record 4 of Set 7 | zaranj
# Processing Record 5 of Set 7 | la libertad
# Processing Record 6 of Set 7 | lazaro cardenas
# Processing Record 7 of Set 7 | the valley
# Processing Record 8 of Set 7 | bafq
# Processing Record 9 of Set 7 | roseau
# Processing Record 10 of Set 7 | longyearbyen
# Processing Record 11 of Set 7 | kavieng
# Processing Record 12 of Set 7 | bengkulu
# Processing Record 13 of Set 7 | arua
# Processing Record 14 of Set 7 | viedma
# Processing Record 15 of Set 7 | hervey bay
# Processing Record 16 of Set 7 | sawakin
# Processing Record 17 of Set 7 | ixtapa
# Processing Record 18 of Set 7 | tiksi
# Processing Record 19 of Set 7 | upernavik
# Processing Record 20 of Set 7 | baykit
# Processing Record 21 of Set 7 | coihaique
# Processing Record 22 of Set 7 | kaabong
# Processing Record 23 of Set 7 | eureka
# Processing Record 24 of Set 7 | osoyoos
# Processing Record 25 of Set 7 | danilovka
# Processing Record 26 of Set 7 | marica
# Processing Record 27 of Set 7 | shaowu
# Processing Record 28 of Set 7 | davila
# Processing Record 29 of Set 7 | bilibino
# Processing Record 30 of Set 7 | plover
# Processing Record 31 of Set 7 | monrovia
# Processing Record 32 of Set 7 | severo-kurilsk
# Processing Record 33 of Set 7 | rohatyn
# Processing Record 34 of Set 7 | kruisfontein
# Processing Record 35 of Set 7 | xianyang
# Processing Record 36 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 7 | touros
# Processing Record 38 of Set 7 | khatima
# Processing Record 39 of Set 7 | henties bay
# Processing Record 40 of Set 7 | coahuayana
# Processing Record 41 of Set 7 | saskylakh
# Processing Record 42 of Set 7 | nuqui
# Processing Record 43 of Set 7 | mukhen
# Processing Record 44 of Set 7 | baijiantan
# Processing Record 45 of Set 7 | poso
# Processing Record 46 of Set 7 | harer
# Processing Record 47 of Set 7 | narasannapeta
# Processing Record 48 of Set 7 | kawalu
# Processing Record 49 of Set 7 | saint-georges
# Processing Record 50 of Set 7 | yarada
# Processing Record 1 of Set 8 | amarante do maranhao
# Processing Record 2 of Set 8 | grand gaube
# Processing Record 3 of Set 8 | la romana
# Processing Record 4 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 8 | zeya
# Processing Record 6 of Set 8 | dosso
# Processing Record 7 of Set 8 | ajuchitlan
# Processing Record 8 of Set 8 | los angeles
# Processing Record 9 of Set 8 | pangai
# Processing Record 10 of Set 8 | shakiso
# Processing Record 11 of Set 8 | saint-pierre
# Processing Record 12 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 13 of Set 8 | mpika
# Processing Record 14 of Set 8 | blythe
# Processing Record 15 of Set 8 | san juan
# Processing Record 16 of Set 8 | meulaboh
# Processing Record 17 of Set 8 | kjollefjord
# Processing Record 18 of Set 8 | shalinskoye
# Processing Record 19 of Set 8 | nur
# Processing Record 20 of Set 8 | kysyl-syr
# Processing Record 21 of Set 8 | tessalit
# Processing Record 22 of Set 8 | kikwit
# Processing Record 23 of Set 8 | clyde river
# Processing Record 24 of Set 8 | marsa matruh
# Processing Record 25 of Set 8 | tlaxiaco
# City not found. Skipping...
# Processing Record 26 of Set 8 | tazovskiy
# Processing Record 27 of Set 8 | cockburn town
# Processing Record 28 of Set 8 | letlhakane
# Processing Record 29 of Set 8 | buala
# Processing Record 30 of Set 8 | luanda
# Processing Record 31 of Set 8 | kashi
# Processing Record 32 of Set 8 | steamboat springs
# Processing Record 33 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 34 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 8 | kamiiso
# Processing Record 36 of Set 8 | cabedelo
# Processing Record 37 of Set 8 | lugovoy
# Processing Record 38 of Set 8 | iqaluit
# Processing Record 39 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 8 | leh
# Processing Record 41 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 42 of Set 8 | hovd
# Processing Record 43 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 8 | sitka
# Processing Record 45 of Set 8 | dongsheng
# Processing Record 46 of Set 8 | araouane
# Processing Record 47 of Set 8 | richards bay
# Processing Record 48 of Set 8 | mimongo
# Processing Record 49 of Set 8 | komsomolskiy
# Processing Record 50 of Set 8 | acapulco
# Processing Record 1 of Set 9 | nuuk
# Processing Record 2 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 3 of Set 9 | zhangjiakou
# Processing Record 4 of Set 9 | belyy yar
# Processing Record 5 of Set 9 | san quintin
# Processing Record 6 of Set 9 | kalaleh
# Processing Record 7 of Set 9 | ponta delgada
# Processing Record 8 of Set 9 | magway
# Processing Record 9 of Set 9 | ishigaki
# Processing Record 10 of Set 9 | gazojak
# Processing Record 11 of Set 9 | caxito
# Processing Record 12 of Set 9 | turukhansk
# Processing Record 13 of Set 9 | dalby
# Processing Record 14 of Set 9 | boshnyakovo
# Processing Record 15 of Set 9 | garowe
# Processing Record 16 of Set 9 | solnechnyy
# Processing Record 17 of Set 9 | presidencia roque saenz pena
# Processing Record 18 of Set 9 | lewisporte
# Processing Record 19 of Set 9 | baruun-urt
# Processing Record 20 of Set 9 | bonthe
# Processing Record 21 of Set 9 | berlevag
# Processing Record 22 of Set 9 | borba
# Processing Record 23 of Set 9 | trofors
# Processing Record 24 of Set 9 | kolaras
# Processing Record 25 of Set 9 | chicama
# Processing Record 26 of Set 9 | niono
# Processing Record 27 of Set 9 | gamba
# Processing Record 28 of Set 9 | alyangula
# Processing Record 29 of Set 9 | belaya gora
# Processing Record 30 of Set 9 | ingham
# Processing Record 31 of Set 9 | andrelandia
# Processing Record 32 of Set 9 | ahuimanu
# Processing Record 33 of Set 9 | kajaani
# Processing Record 34 of Set 9 | guerrero negro
# Processing Record 35 of Set 9 | lavrentiya
# Processing Record 36 of Set 9 | xinmin
# Processing Record 37 of Set 9 | dingle
# Processing Record 38 of Set 9 | okhotsk
# Processing Record 39 of Set 9 | trairi
# Processing Record 40 of Set 9 | cairns
# Processing Record 41 of Set 9 | ternate
# Processing Record 42 of Set 9 | porgera
# Processing Record 43 of Set 9 | ankang
# Processing Record 44 of Set 9 | gopalpur
# Processing Record 45 of Set 9 | batagay
# Processing Record 46 of Set 9 | aljezur
# Processing Record 47 of Set 9 | verkhovazhye
# Processing Record 48 of Set 9 | wanaka
# Processing Record 49 of Set 9 | porangatu
# Processing Record 50 of Set 9 | adrar
# Processing Record 1 of Set 10 | dalaba
# Processing Record 2 of Set 10 | hofn
# Processing Record 3 of Set 10 | atlantic city
# Processing Record 4 of Set 10 | rancho palos verdes
# Processing Record 5 of Set 10 | ketou
# Processing Record 6 of Set 10 | ornskoldsvik
# Processing Record 7 of Set 10 | aklavik
# Processing Record 8 of Set 10 | mouzakion
# City not found. Skipping...
# Processing Record 9 of Set 10 | sao joao de pirabas
# Processing Record 10 of Set 10 | adilabad
# Processing Record 11 of Set 10 | aldan
# Processing Record 12 of Set 10 | terrace
# Processing Record 13 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 14 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 10 | abu jubayhah
# City not found. Skipping...
# Processing Record 16 of Set 10 | ola
# Processing Record 17 of Set 10 | plettenberg bay
# Processing Record 18 of Set 10 | san cristobal
# Processing Record 19 of Set 10 | newberg
# Processing Record 20 of Set 10 | mnogovershinnyy
# Processing Record 21 of Set 10 | pangnirtung
# Processing Record 22 of Set 10 | omboue
# Processing Record 23 of Set 10 | panaba
# Processing Record 24 of Set 10 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 25 of Set 10 | beloha
# Processing Record 26 of Set 10 | benguela
# Processing Record 27 of Set 10 | srednekolymsk
# Processing Record 28 of Set 10 | tikhvin
# Processing Record 29 of Set 10 | palmer
# Processing Record 30 of Set 10 | xining
# Processing Record 31 of Set 10 | san juan de los morros
# Processing Record 32 of Set 10 | abu dhabi
# Processing Record 33 of Set 10 | zlobin
# Processing Record 34 of Set 10 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 35 of Set 10 | santa cruz
# Processing Record 36 of Set 10 | lagoa
# Processing Record 37 of Set 10 | yumen
# Processing Record 38 of Set 10 | rawson
# Processing Record 39 of Set 10 | waitati
# Processing Record 40 of Set 10 | charters towers
# Processing Record 41 of Set 10 | svarstad
# Processing Record 42 of Set 10 | rio grande
# Processing Record 43 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 10 | a coruna
# Processing Record 45 of Set 10 | erenhot
# Processing Record 46 of Set 10 | ciudad bolivar
# Processing Record 47 of Set 10 | berdigestyakh
# Processing Record 48 of Set 10 | ostersund
# Processing Record 49 of Set 10 | saint-francois
# Processing Record 50 of Set 10 | nachingwea
# Processing Record 1 of Set 11 | marawi
# Processing Record 2 of Set 11 | kamaishi
# Processing Record 3 of Set 11 | jaque
# Processing Record 4 of Set 11 | naze
# Processing Record 5 of Set 11 | ayr
# Processing Record 6 of Set 11 | vallenar
# Processing Record 7 of Set 11 | chapais
# Processing Record 8 of Set 11 | wanxian
# Processing Record 9 of Set 11 | lasa
# Processing Record 10 of Set 11 | zonguldak
# Processing Record 11 of Set 11 | humaita
# Processing Record 12 of Set 11 | prado
# Processing Record 13 of Set 11 | ahipara
# Processing Record 14 of Set 11 | martapura
# Processing Record 15 of Set 11 | collie
# Processing Record 16 of Set 11 | new albany
# Processing Record 17 of Set 11 | amuntai
# Processing Record 18 of Set 11 | salinopolis
# Processing Record 19 of Set 11 | ukiah
# Processing Record 20 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 21 of Set 11 | venice
# Processing Record 22 of Set 11 | klaksvik
# Processing Record 23 of Set 11 | kyren
# Processing Record 24 of Set 11 | chipinge
# Processing Record 25 of Set 11 | somanda
# Processing Record 26 of Set 11 | ampanihy
# Processing Record 27 of Set 11 | jumla
# Processing Record 28 of Set 11 | maceio
# Processing Record 29 of Set 11 | koroni
# Processing Record 30 of Set 11 | antofagasta
# Processing Record 31 of Set 11 | dong hoi
# Processing Record 32 of Set 11 | mataundh
# Processing Record 33 of Set 11 | wanning
# Processing Record 34 of Set 11 | margate
# Processing Record 35 of Set 11 | prainha
# Processing Record 36 of Set 11 | kununurra
# Processing Record 37 of Set 11 | laguna
# Processing Record 38 of Set 11 | cah ab
# City not found. Skipping...
# Processing Record 39 of Set 11 | kholmskaya
# Processing Record 40 of Set 11 | sisimiut
# Processing Record 41 of Set 11 | byron bay
# Processing Record 42 of Set 11 | matai
# Processing Record 43 of Set 11 | carahue
# Processing Record 44 of Set 11 | norman wells
# Processing Record 45 of Set 11 | la rioja
# Processing Record 46 of Set 11 | komyshnya
# Processing Record 47 of Set 11 | sulina
# Processing Record 48 of Set 11 | la palma
# Processing Record 49 of Set 11 | lukulu
# Processing Record 50 of Set 11 | paka
# Processing Record 1 of Set 12 | redmond
# Processing Record 2 of Set 12 | aswan
# Processing Record 3 of Set 12 | ribeira brava
# Processing Record 4 of Set 12 | emba
# Processing Record 5 of Set 12 | ust-tsilma
# Processing Record 6 of Set 12 | teguldet
# Processing Record 7 of Set 12 | krasnokamensk
# Processing Record 8 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 9 of Set 12 | bulgan
# Processing Record 10 of Set 12 | sinnamary
# Processing Record 11 of Set 12 | kinel-cherkassy
# Processing Record 12 of Set 12 | cap malheureux
# Processing Record 13 of Set 12 | midyat
# Processing Record 14 of Set 12 | san andres
# Processing Record 15 of Set 12 | xingyi
# Processing Record 16 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 12 | chiny
# Processing Record 18 of Set 12 | vao
# Processing Record 19 of Set 12 | fortuna
# Processing Record 20 of Set 12 | birjand
# Processing Record 21 of Set 12 | tabuk
# Processing Record 22 of Set 12 | mabaruma
# Processing Record 23 of Set 12 | bandipur
# Processing Record 24 of Set 12 | escuinapa
# Processing Record 25 of Set 12 | dekar
# Processing Record 26 of Set 12 | urusha
# Processing Record 27 of Set 12 | camana
# Processing Record 28 of Set 12 | saint austell
# Processing Record 29 of Set 12 | suicheng
# Processing Record 30 of Set 12 | tumkur
# Processing Record 31 of Set 12 | udgir
# Processing Record 32 of Set 12 | camopi
# Processing Record 33 of Set 12 | manta
# Processing Record 34 of Set 12 | chaman
# Processing Record 35 of Set 12 | aripuana
# Processing Record 36 of Set 12 | seryshevo
# Processing Record 37 of Set 12 | valdivia
# Processing Record 38 of Set 12 | brighton
# Processing Record 39 of Set 12 | zelenokumsk
# Processing Record 40 of Set 12 | pitimbu
# Processing Record 41 of Set 12 | madang
# Processing Record 42 of Set 12 | abu samrah
# Processing Record 43 of Set 12 | kholtoson
# Processing Record 44 of Set 12 | monterey
# Processing Record 45 of Set 12 | ouesso
# Processing Record 46 of Set 12 | baturinskaya
# Processing Record 47 of Set 12 | nabire
# Processing Record 48 of Set 12 | itaituba
# Processing Record 49 of Set 12 | akdepe
# Processing Record 50 of Set 12 | gokak
# Processing Record 1 of Set 13 | montevideo
# Processing Record 2 of Set 13 | sept-iles
# Processing Record 3 of Set 13 | constitucion
# Processing Record 4 of Set 13 | fredericksburg
# Processing Record 5 of Set 13 | bathsheba
# Processing Record 6 of Set 13 | valle hermoso
# Processing Record 7 of Set 13 | gravdal
# Processing Record 8 of Set 13 | save
# Processing Record 9 of Set 13 | kemin
# Processing Record 10 of Set 13 | kampot
# Processing Record 11 of Set 13 | itaqui
# Processing Record 12 of Set 13 | lashio
# Processing Record 13 of Set 13 | tromso
# Processing Record 14 of Set 13 | solwezi
# Processing Record 15 of Set 13 | yingcheng
# Processing Record 16 of Set 13 | boone
# Processing Record 17 of Set 13 | diego de almagro
# Processing Record 18 of Set 13 | oranjemund
# Processing Record 19 of Set 13 | manzil tamim
# City not found. Skipping...
# Processing Record 20 of Set 13 | camocim
# Processing Record 21 of Set 13 | nago
# Processing Record 22 of Set 13 | beyneu
# Processing Record 23 of Set 13 | savelugu
# Processing Record 24 of Set 13 | talas
# Processing Record 25 of Set 13 | riviere-au-renard
# Processing Record 26 of Set 13 | namibe
# Processing Record 27 of Set 13 | ilinskiy
# Processing Record 28 of Set 13 | parras
# City not found. Skipping...
# Processing Record 29 of Set 13 | kalmunai
# Processing Record 30 of Set 13 | clarence town
# Processing Record 31 of Set 13 | klaeng
# Processing Record 32 of Set 13 | niesky
# Processing Record 33 of Set 13 | stromness
# Processing Record 34 of Set 13 | leshukonskoye
# Processing Record 35 of Set 13 | pizarro
# Processing Record 36 of Set 13 | mishelevka
# Processing Record 37 of Set 13 | ratnagiri
# Processing Record 38 of Set 13 | bekhteyevka
# Processing Record 39 of Set 13 | bijapur
# Processing Record 40 of Set 13 | campos belos
# Processing Record 41 of Set 13 | bozhou
# Processing Record 42 of Set 13 | chinsali
# Processing Record 43 of Set 13 | ucluelet
# Processing Record 44 of Set 13 | adre
# Processing Record 45 of Set 13 | burica
# City not found. Skipping...
# Processing Record 46 of Set 13 | san clemente
# Processing Record 47 of Set 13 | andros town
# Processing Record 48 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 49 of Set 13 | shimoda
# Processing Record 50 of Set 13 | nyurba
# Processing Record 1 of Set 14 | lorca
# Processing Record 2 of Set 14 | barahona
# Processing Record 3 of Set 14 | artyom
# Processing Record 4 of Set 14 | balassagyarmat
# Processing Record 5 of Set 14 | grand island
# Processing Record 6 of Set 14 | prince rupert
# Processing Record 7 of Set 14 | sulangan
# Processing Record 8 of Set 14 | luhyny
# Processing Record 9 of Set 14 | mokhsogollokh
# Processing Record 10 of Set 14 | ormara
# Processing Record 11 of Set 14 | khasan
# Processing Record 12 of Set 14 | champerico
# Processing Record 13 of Set 14 | valentin gomez farias
# Processing Record 14 of Set 14 | port-gentil
# Processing Record 15 of Set 14 | soe
# Processing Record 16 of Set 14 | sur
# Processing Record 17 of Set 14 | mount isa
# Processing Record 18 of Set 14 | rabaul
# Processing Record 19 of Set 14 | mitu
# Processing Record 20 of Set 14 | mayo
# Processing Record 21 of Set 14 | kyra
# Processing Record 22 of Set 14 | anloga
# Processing Record 23 of Set 14 | santa fe
# Processing Record 24 of Set 14 | ossora
# Processing Record 25 of Set 14 | betioky
# Processing Record 26 of Set 14 | luang prabang
# Processing Record 27 of Set 14 | caninde
# Processing Record 28 of Set 14 | portland
# Processing Record 29 of Set 14 | rameswaram
# Processing Record 30 of Set 14 | liverpool
# Processing Record 31 of Set 14 | moussoro
# Processing Record 32 of Set 14 | hurghada
# Processing Record 33 of Set 14 | jomalig
# City not found. Skipping...
# Processing Record 34 of Set 14 | bardiyah
# Processing Record 35 of Set 14 | uralets
# Processing Record 36 of Set 14 | stykkisholmur
# Processing Record 37 of Set 14 | ji-parana
# City not found. Skipping...
# Processing Record 38 of Set 14 | quatre cocos
# Processing Record 39 of Set 14 | sernur
# Processing Record 40 of Set 14 | talaya
# Processing Record 41 of Set 14 | spanaway
# Processing Record 42 of Set 14 | madimba
# Processing Record 43 of Set 14 | bisho
# Processing Record 44 of Set 14 | port blair
# Processing Record 45 of Set 14 | sevsk
# Processing Record 46 of Set 14 | vangaindrano
# Processing Record 47 of Set 14 | pandan
# Processing Record 48 of Set 14 | meridian
# Processing Record 49 of Set 14 | blytheville
# Processing Record 50 of Set 14 | warrnambool
# Processing Record 1 of Set 15 | san jose
# Processing Record 2 of Set 15 | babayurt
# Processing Record 3 of Set 15 | san vicente
# Processing Record 4 of Set 15 | nikolayevsk-na-amure
# Processing Record 5 of Set 15 | lincoln
# Processing Record 6 of Set 15 | newport
# Processing Record 7 of Set 15 | zhanaozen
# Processing Record 8 of Set 15 | cortez
# Processing Record 9 of Set 15 | biak
# Processing Record 10 of Set 15 | skiros
# City not found. Skipping...
# Processing Record 11 of Set 15 | impfondo
# Processing Record 12 of Set 15 | nyrob
# Processing Record 13 of Set 15 | embonas
# Processing Record 14 of Set 15 | iskateley
# Processing Record 15 of Set 15 | trzcianka
# Processing Record 16 of Set 15 | bara
# Processing Record 17 of Set 15 | carutapera
# Processing Record 18 of Set 15 | makakilo city
# Processing Record 19 of Set 15 | povenets
# Processing Record 20 of Set 15 | lata
# Processing Record 21 of Set 15 | cazanesti
# Processing Record 22 of Set 15 | grandview
# Processing Record 23 of Set 15 | san carlos de bariloche
# Processing Record 24 of Set 15 | ugoofaaru
# Processing Record 25 of Set 15 | vresina
# Processing Record 26 of Set 15 | dunedin
# Processing Record 27 of Set 15 | eslov
# Processing Record 28 of Set 15 | ust-kuyga
# Processing Record 29 of Set 15 | najran
# Processing Record 30 of Set 15 | visnes
# Processing Record 31 of Set 15 | qeshm
# Processing Record 32 of Set 15 | dargaville
# Processing Record 33 of Set 15 | huaicheng
# Processing Record 34 of Set 15 | sagua de tanamo
# Processing Record 35 of Set 15 | grimshaw
# Processing Record 36 of Set 15 | muli
# Processing Record 37 of Set 15 | launceston
# Processing Record 38 of Set 15 | sinegorye
# Processing Record 39 of Set 15 | gryfice
# Processing Record 40 of Set 15 | cravo norte
# Processing Record 41 of Set 15 | bondo
# Processing Record 42 of Set 15 | sola
# Processing Record 43 of Set 15 | am timan
# Processing Record 44 of Set 15 | banikoara
# Processing Record 45 of Set 15 | manali
# Processing Record 46 of Set 15 | thunder bay
# Processing Record 47 of Set 15 | navahrudak
# Processing Record 48 of Set 15 | estelle
# Processing Record 49 of Set 15 | lubango
# Processing Record 50 of Set 15 | hebertville
# City not found. Skipping...
# Processing Record 1 of Set 16 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 16 | egvekinot
# Processing Record 3 of Set 16 | zacualpan
# Processing Record 4 of Set 16 | karratha
# Processing Record 5 of Set 16 | griffith
# Processing Record 6 of Set 16 | troina
# Processing Record 7 of Set 16 | meadow lake
# Processing Record 8 of Set 16 | muros
# Processing Record 9 of Set 16 | nelson bay
# Processing Record 10 of Set 16 | narathiwat
# Processing Record 11 of Set 16 | hamilton
# Processing Record 12 of Set 16 | amalapuram
# Processing Record 13 of Set 16 | kuche
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 704

# %% [markdown]
# Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                 Takanabe  32.1333  131.5000     44.49        66          83
# 1                  Ushuaia -54.8000  -68.3000     38.86        93         100
# 2              Tuktoyaktuk  69.4541 -133.0374    -27.40        68          20
# 3              Yellowknife  62.4560 -114.3525     -3.48        84         100
# 4               Butaritari   3.0707  172.7902     80.33        81          66
# 5              Port Alfred -33.5906   26.8910     68.18        90           6
# 6              Provideniya  64.3833 -173.3000      8.71        78          40
# 7  Brezovica Pri Ljubljani  46.0333   14.4000     43.38        80         100
# 8               Nikolskoye  59.7035   30.7861     28.29        95         100
# 9              New Norfolk -42.7826  147.0587     84.92        39         100
#
#    Wind Speed Country                 Date Current Description
# 0        3.40      JP  2022-12-27 22:24:29       broken clouds
# 1       35.68      AR  2022-12-27 22:13:31       moderate rain
# 2        3.44      CA  2022-12-27 22:17:55          few clouds
# 3       10.36      CA  2022-12-27 22:20:51          light snow
# 4       16.71      KI  2022-12-27 22:16:47          light rain
# 5        7.00      ZA  2022-12-27 22:18:02           clear sky
# 6       22.37      RU  2022-12-27 22:15:38    scattered clouds
# 7        4.27      SI  2022-12-27 22:25:11     overcast clouds
# 8        7.05      RU  2022-12-27 22:16:49     overcast clouds
# 9       11.99      AU  2022-12-27 22:25:11          light rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]



# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#                       City Country                 Date      Lat       Lng  \
# 0                 Takanabe      JP  2022-12-27 22:24:29  32.1333  131.5000
# 1                  Ushuaia      AR  2022-12-27 22:13:31 -54.8000  -68.3000
# 2              Tuktoyaktuk      CA  2022-12-27 22:17:55  69.4541 -133.0374
# 3              Yellowknife      CA  2022-12-27 22:20:51  62.4560 -114.3525
# 4               Butaritari      KI  2022-12-27 22:16:47   3.0707  172.7902
# 5              Port Alfred      ZA  2022-12-27 22:18:02 -33.5906   26.8910
# 6              Provideniya      RU  2022-12-27 22:15:38  64.3833 -173.3000
# 7  Brezovica Pri Ljubljani      SI  2022-12-27 22:25:11  46.0333   14.4000
# 8               Nikolskoye      RU  2022-12-27 22:16:49  59.7035   30.7861
# 9              New Norfolk      AU  2022-12-27 22:25:11 -42.7826  147.0587
#
#    Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 0     44.49        66          83        3.40       broken clouds
# 1     38.86        93         100       35.68       moderate rain
# 2    -27.40        68          20        3.44          few clouds
# 3     -3.48        84         100       10.36          light snow
# 4     80.33        81          66       16.71          light rain
# 5     68.18        90           6        7.00           clear sky
# 6      8.71        78          40       22.37    scattered clouds
# 7     43.38        80         100        4.27     overcast clouds
# 8     28.29        95         100        7.05     overcast clouds
# 9     84.92        39         100       11.99          light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Date                    object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
